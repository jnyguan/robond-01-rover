# %%
# %run drive_rover.py
# Out:
# Perception.py run
# NOT recording this run ...
# (48054) wsgi starting up on http://0.0.0.0:4567
# (48054) accepted ('127.0.0.1', 60852)
# connect  2f734a3846804afaa65482ff48814ee7
# Current FPS: 1
# dict_keys(['roll', 'fixed_turn', 'image', 'picking_up', 'steering_angle', 'samples_y', 'samples_x', 'brake', 'sample_count', 'position', 'pitch', 'yaw', 'throttle', 'speed', 'near_sample'])
# speed = 0.0 position = [ 99.67   85.589] throttle = 0.0 steer_angle = 0.0 near_sample 0 picking_up 0
# 99.67
# 85.589
# perception_step successful
# Current FPS: 1
# dict_keys(['roll', 'fixed_turn', 'image', 'picking_up', 'steering_angle', 'samples_y', 'samples_x', 'brake', 'sample_count', 'position', 'pitch', 'yaw', 'throttle', 'speed', 'near_sample'])
# speed = 0.0 position = [ 99.67   85.589] throttle = 0.0 steer_angle = 0.0 near_sample 0 picking_up 0
# 99.67
# 85.589
# perception_step successful
# Current FPS: 1
# ...

# %%
# %matplotlib inline

r_image = mpimg.imread('Rover.img')

plt.imshow(r_image)
# plt.show
